# %% [markdown]
# # pyWebExpo - Informedvar

# %%
# Import the src/pywebexpo module

import sys
sys.path.append('../src/pywebexpo')

# %%
from seg_models.informedvar import SEGInformedVarLognormal

# %%
# Create a new instance of the SEGInformedVarLognormal class

basic_data = ['24.7', '64.1', '13.8', '43.7', '19.9', '133', '32.1', '15', '53.7']

oel = 100
model = SEGInformedVarLognormal(data = basic_data, oel = oel)

# %%
model.fit()
# Out:
# {'draws': 5000, 'tune': 4000, 'chains': 6, 'target_accept': 0.85, 'nuts_sampler': 'numpyro', 'initvals': {'mu': -1.2039728043259361, 'log_sigma': 0.9162907318741551}}
# ...
#   0%|          | 0/9000 [00:00<?, ?it/s]
#        mu ~ Uniform(-20, 20)
# log_sigma ~ Normal(-0.174, f())
#     sigma ~ Deterministic(f(log_sigma))
#         y ~ Censored(LogNormal(mu, sigma), <constant>, <constant>)

# %%
model.analyse_chains()
# Out:
# {'gm': {'est': 34.168, 'lcl': 24.075, 'ucl': 48.297},
#  'gsd': {'est': 2.179, 'lcl': 1.795, 'ucl': 2.986},
#  'frac': {'est': 8.269, 'lcl': 2.234, 'ucl': 21.02},
#  'perc': {'est': 122.24, 'lcl': 79.479, 'ucl': 233.157},
#  'am': {'est': 46.617, 'lcl': 33.162, 'ucl': 74.877},
#  'frac.risk': 41.013,
#  'perc.risk': 70.37,
#  'am.risk': 3.523,
#  'am.riskbands': {'<0.01*OEL': 0.0,
#   '[0.01-0.1]*OEL': 0.0,
#   '[0.1-0.5]*OEL': 58.9,
#   '[0.5-1]*OEL': 37.577,
#   '>OEL': 3.523}}

# %%
model.idata
# Out:
# Inference data with groups:
# 	> posterior
# 	> sample_stats
# 	> observed_data
# 	> constant_data
